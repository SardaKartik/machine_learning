# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib 
matplotlib.rcParams["figure.figsize"] = (20,10)

# %% [markdown]
# import necessary library whcih we need in this project

# %%
df=pd.read_csv("Bengaluru_House_Data.csv")

# %% [markdown]
# import data by using read_csv

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.area_type
# Out:
# 0        Super built-up  Area
# 1                  Plot  Area
# 2              Built-up  Area
# 3        Super built-up  Area
# 4        Super built-up  Area
#                  ...
# 13315          Built-up  Area
# 13316    Super built-up  Area
# 13317          Built-up  Area
# 13318    Super built-up  Area
# 13319    Super built-up  Area
# Name: area_type, Length: 13320, dtype: object

# %%
df.groupby('area_type')['area_type'].count()
# Out:
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.drop(['area_type','society','balcony','availability'],axis='columns',inplace=True)

# %%
df
# Out:
#                        location       size total_sqft  bath   price
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0   51.00
# ...                         ...        ...        ...   ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0   17.00
#
# [13320 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %% [markdown]
# knowing about the null value
# or doing data cleaning by knowing the number of nan value

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                        location       size total_sqft  bath   price
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0   51.00
# ...                         ...        ...        ...   ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0   17.00
#
# [13246 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %% [markdown]
# since we have large number of data so we drop the row which has na vale

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df['BHK']=df['size'].apply(lambda x: int(x.split(" ")[0]))

# %%
df
# Out:
#                        location       size total_sqft  bath   price  BHK
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    4
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00    3
# 4                      Kothanur      2 BHK       1200   2.0   51.00    2
# ...                         ...        ...        ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00    5
# 13316             Richards Town      4 BHK       3600   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00    4
# 13319              Doddathoguru      1 BHK        550   1.0   17.00    1
#
# [13246 rows x 6 columns]

# %%
df['BHK'].unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18], dtype=int64)

# %%
df.drop('size',axis='columns',inplace=True)

# %%
df
# Out:
#                        location total_sqft  bath   price  BHK
# 0      Electronic City Phase II       1056   2.0   39.07    2
# 1              Chikka Tirupathi       2600   5.0  120.00    4
# 2                   Uttarahalli       1440   2.0   62.00    3
# 3            Lingadheeranahalli       1521   3.0   95.00    3
# 4                      Kothanur       1200   2.0   51.00    2
# ...                         ...        ...   ...     ...  ...
# 13315                Whitefield       3453   4.0  231.00    5
# 13316             Richards Town       3600   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar       1141   2.0   60.00    2
# 13318           Padmanabhanagar       4689   4.0  488.00    4
# 13319              Doddathoguru        550   1.0   17.00    1
#
# [13246 rows x 5 columns]

# %%
df['BHK'].unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18], dtype=int64)

# %%
df[df.BHK>20]
# Out:
#                        location total_sqft  bath  price  BHK
# 1718  2Electronic City Phase II       8000  27.0  230.0   27
# 4684                Munnekollal       2400  40.0  660.0   43

# %%
df['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
df[~df['total_sqft'].apply(is_float)]
# Out:
#                  location   total_sqft  bath    price  BHK
# 30              Yelahanka  2100 - 2850   4.0  186.000    4
# 122                Hebbal  3067 - 8156   4.0  477.000    4
# 137    8th Phase JP Nagar  1042 - 1105   2.0   54.005    2
# 165              Sarjapur  1145 - 1340   2.0   43.490    2
# 188              KR Puram  1015 - 1540   2.0   56.800    2
# ...                   ...          ...   ...      ...  ...
# 12975          Whitefield   850 - 1060   2.0   38.190    2
# 12990      Talaghattapura  1804 - 2273   3.0  122.000    3
# 13059              Harlur  1200 - 1470   2.0   72.760    2
# 13265               Hoodi  1133 - 1384   2.0   59.135    2
# 13299          Whitefield  2830 - 2882   5.0  154.500    4
#
# [190 rows x 5 columns]

# %%
df[~df['total_sqft'].apply(is_float)].head(10)
# Out:
#                location      total_sqft  bath    price  BHK
# 30            Yelahanka     2100 - 2850   4.0  186.000    4
# 122              Hebbal     3067 - 8156   4.0  477.000    4
# 137  8th Phase JP Nagar     1042 - 1105   2.0   54.005    2
# 165            Sarjapur     1145 - 1340   2.0   43.490    2
# 188            KR Puram     1015 - 1540   2.0   56.800    2
# 410             Kengeri  34.46Sq. Meter   1.0   18.500    1
# 549         Hennur Road     1195 - 1440   2.0   63.770    2
# 648             Arekere       4125Perch   9.0  265.000    9
# 661           Yelahanka     1120 - 1145   2.0   48.130    2
# 672        Bettahalsoor     3090 - 5002   4.0  445.000    4

# %%
def convert_sqft_to_num(x):
    tokens=x.split('-')
    if(len(tokens)==2):
        return (float(tokens[0])+float(tokens[1])/2)
    try:
        return float(x)
    except:
        return None

# %%
convert_sqft_to_num('1500')
# Out:
# 1500.0

# %%
convert_sqft_to_num('1500cms')

# %%
df['total_sqft']=df['total_sqft'].apply(convert_sqft_to_num)

# %%
df
# Out:
#                        location  total_sqft  bath   price  BHK
# 0      Electronic City Phase II      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi      2600.0   5.0  120.00    4
# 2                   Uttarahalli      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      1521.0   3.0   95.00    3
# 4                      Kothanur      1200.0   2.0   51.00    2
# ...                         ...         ...   ...     ...  ...
# 13315                Whitefield      3453.0   4.0  231.00    5
# 13316             Richards Town      3600.0   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      1141.0   2.0   60.00    2
# 13318           Padmanabhanagar      4689.0   4.0  488.00    4
# 13319              Doddathoguru       550.0   1.0   17.00    1
#
# [13246 rows x 5 columns]

# %%
df.total_sqft
# Out:
# 0        1056.0
# 1        2600.0
# 2        1440.0
# 3        1521.0
# 4        1200.0
#           ...
# 13315    3453.0
# 13316    3600.0
# 13317    1141.0
# 13318    4689.0
# 13319     550.0
# Name: total_sqft, Length: 13246, dtype: float64

# %%
df.isnull().sum()
# Out:
# location       0
# total_sqft    46
# bath           0
# price          0
# BHK            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                        location  total_sqft  bath   price  BHK
# 0      Electronic City Phase II      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi      2600.0   5.0  120.00    4
# 2                   Uttarahalli      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      1521.0   3.0   95.00    3
# 4                      Kothanur      1200.0   2.0   51.00    2
# ...                         ...         ...   ...     ...  ...
# 13315                Whitefield      3453.0   4.0  231.00    5
# 13316             Richards Town      3600.0   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      1141.0   2.0   60.00    2
# 13318           Padmanabhanagar      4689.0   4.0  488.00    4
# 13319              Doddathoguru       550.0   1.0   17.00    1
#
# [13200 rows x 5 columns]

# %%
df['price_per_sq_ft']=df['price']*100000/df['total_sqft']

# %%
df
# Out:
#                        location  total_sqft  bath   price  BHK  \
# 0      Electronic City Phase II      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi      2600.0   5.0  120.00    4
# 2                   Uttarahalli      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      1521.0   3.0   95.00    3
# 4                      Kothanur      1200.0   2.0   51.00    2
# ...                         ...         ...   ...     ...  ...
# 13315                Whitefield      3453.0   4.0  231.00    5
# 13316             Richards Town      3600.0   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      1141.0   2.0   60.00    2
# 13318           Padmanabhanagar      4689.0   4.0  488.00    4
# 13319              Doddathoguru       550.0   1.0   17.00    1
#
#        price_per_sq_ft
# 0          3699.810606
# 1          4615.384615
# 2          4305.555556
# 3          6245.890861
# 4          4250.000000
# ...                ...
# 13315      6689.834926
# ...

# %%
len(df['location'].unique())
# Out:
# 1298

# %%
df.location
# Out:
# 0        Electronic City Phase II
# 1                Chikka Tirupathi
# 2                     Uttarahalli
# 3              Lingadheeranahalli
# 4                        Kothanur
#                    ...
# 13315                  Whitefield
# 13316               Richards Town
# 13317       Raja Rajeshwari Nagar
# 13318             Padmanabhanagar
# 13319                Doddathoguru
# Name: location, Length: 13200, dtype: object

# %%
df.location=df.location.apply(lambda x : x.strip())

# %% [markdown]
# python string stirp function is an inbuilt function in the python programming language that return a copy of the string with both leading and trailing characters removed(based on the string argument passed )

# %%
df.location
# Out:
# 0        Electronic City Phase II
# 1                Chikka Tirupathi
# 2                     Uttarahalli
# 3              Lingadheeranahalli
# 4                        Kothanur
#                    ...
# 13315                  Whitefield
# 13316               Richards Town
# 13317       Raja Rajeshwari Nagar
# 13318             Padmanabhanagar
# 13319                Doddathoguru
# Name: location, Length: 13200, dtype: object

# %%
location_stats=df.groupby('location')['location'].agg('count').sort_values(ascending=False)

# %%
location_stats
# Out:
# location
# Whitefield               533
# Sarjapur  Road           392
# Electronic City          304
# Kanakpura Road           264
# Thanisandra              235
#                         ...
# 1 Giri Nagar               1
# Kanakapura Road,           1
# Kanakapura main  Road      1
# Kannur                     1
# whitefiled                 1
# Name: location, Length: 1287, dtype: int64

# %%
len(location_stats[location_stats<=10])
# Out:
# 1047

# %%
location_stats_less_than_10=location_stats[location_stats<=10]

# %%
location_stats_less_than_10
# Out:
# location
# Sadashiva Nagar          10
# Naganathapura            10
# Basapura                 10
# Nagadevanahalli          10
# Kalkere                  10
#                          ..
# 1 Giri Nagar              1
# Kanakapura Road,          1
# Kanakapura main  Road     1
# Kannur                    1
# whitefiled                1
# Name: location, Length: 1047, dtype: int64

# %%
df.location=df.location.apply(lambda x: 'other' if x in location_stats_less_than_10 else x)

# %%
df.location
# Out:
# 0        Electronic City Phase II
# 1                Chikka Tirupathi
# 2                     Uttarahalli
# 3              Lingadheeranahalli
# 4                        Kothanur
#                    ...
# 13315                  Whitefield
# 13316                       other
# 13317       Raja Rajeshwari Nagar
# 13318             Padmanabhanagar
# 13319                Doddathoguru
# Name: location, Length: 13200, dtype: object

# %%
len(df.location.unique())
# Out:
# 241

# %%
df.head(20)
# Out:
#                     location  total_sqft  bath   price  BHK  price_per_sq_ft
# 0   Electronic City Phase II      1056.0   2.0   39.07    2      3699.810606
# 1           Chikka Tirupathi      2600.0   5.0  120.00    4      4615.384615
# 2                Uttarahalli      1440.0   2.0   62.00    3      4305.555556
# 3         Lingadheeranahalli      1521.0   3.0   95.00    3      6245.890861
# 4                   Kothanur      1200.0   2.0   51.00    2      4250.000000
# 5                 Whitefield      1170.0   2.0   38.00    2      3247.863248
# 6           Old Airport Road      2732.0   4.0  204.00    4      7467.057101
# 7               Rajaji Nagar      3300.0   4.0  600.00    4     18181.818182
# 8               Marathahalli      1310.0   3.0   63.25    3      4828.244275
# 9                      other      1020.0   6.0  370.00    6     36274.509804
# 10                Whitefield      1800.0   2.0   70.00    3      3888.888889
# ...

# %%
df['total_sqft_per_BHK']=df['total_sqft']/df['BHK']

# %%
df.head(20)
# Out:
#                     location  total_sqft  bath   price  BHK  price_per_sq_ft  \
# 0   Electronic City Phase II      1056.0   2.0   39.07    2      3699.810606
# 1           Chikka Tirupathi      2600.0   5.0  120.00    4      4615.384615
# 2                Uttarahalli      1440.0   2.0   62.00    3      4305.555556
# 3         Lingadheeranahalli      1521.0   3.0   95.00    3      6245.890861
# 4                   Kothanur      1200.0   2.0   51.00    2      4250.000000
# 5                 Whitefield      1170.0   2.0   38.00    2      3247.863248
# 6           Old Airport Road      2732.0   4.0  204.00    4      7467.057101
# 7               Rajaji Nagar      3300.0   4.0  600.00    4     18181.818182
# 8               Marathahalli      1310.0   3.0   63.25    3      4828.244275
# 9                      other      1020.0   6.0  370.00    6     36274.509804
# 10                Whitefield      1800.0   2.0   70.00    3      3888.888889
# ...

# %%
df[df.total_sqft_per_BHK<=300].head()
# Out:
#                location  total_sqft  bath  price  BHK  price_per_sq_ft  \
# 9                 other      1020.0   6.0  370.0    6     36274.509804
# 45           HSR Layout       600.0   9.0  200.0    8     33333.333333
# 58        Murugeshpalya      1407.0   4.0  150.0    6     10660.980810
# 68  Devarachikkanahalli      1350.0   7.0   85.0    8      6296.296296
# 70                other       500.0   3.0  100.0    3     20000.000000
#
#     total_sqft_per_BHK
# 9           170.000000
# 45           75.000000
# 58          234.500000
# 68          168.750000
# 70          166.666667

# %%
df.shape
# Out:
# (13200, 7)

# %%
df=df[~(df.total_sqft_per_BHK<=300)]

# %% [markdown]
# removing the rows which has total_sqft_per_BHK IS LESS THAN 300

# %%
df.shape
# Out:
# (12274, 7)

# %%
df.head()
# Out:
#                    location  total_sqft  bath   price  BHK  price_per_sq_ft  \
# 0  Electronic City Phase II      1056.0   2.0   39.07    2      3699.810606
# 1          Chikka Tirupathi      2600.0   5.0  120.00    4      4615.384615
# 2               Uttarahalli      1440.0   2.0   62.00    3      4305.555556
# 3        Lingadheeranahalli      1521.0   3.0   95.00    3      6245.890861
# 4                  Kothanur      1200.0   2.0   51.00    2      4250.000000
#
#    total_sqft_per_BHK
# 0               528.0
# 1               650.0
# 2               480.0
# 3               507.0
# 4               600.0

# %%
df1=df.drop('total_sqft_per_BHK',axis='columns')

# %%
df1.head()
# Out:
#                    location  total_sqft  bath   price  BHK  price_per_sq_ft
# 0  Electronic City Phase II      1056.0   2.0   39.07    2      3699.810606
# 1          Chikka Tirupathi      2600.0   5.0  120.00    4      4615.384615
# 2               Uttarahalli      1440.0   2.0   62.00    3      4305.555556
# 3        Lingadheeranahalli      1521.0   3.0   95.00    3      6245.890861
# 4                  Kothanur      1200.0   2.0   51.00    2      4250.000000

# %%
df1.shape
# Out:
# (12274, 6)

# %%
df1.price_per_sq_ft
# Out:
# 0         3699.810606
# 1         4615.384615
# 2         4305.555556
# 3         6245.890861
# 4         4250.000000
#              ...
# 13315     6689.834926
# 13316    11111.111111
# 13317     5258.545136
# 13318    10407.336319
# 13319     3090.909091
# Name: price_per_sq_ft, Length: 12274, dtype: float64

# %%
df1.price_per_sq_ft.describe()
# Out:
# count     12274.000000
# mean       6193.407474
# std        4060.592628
# min         267.829813
# 25%        4171.779141
# 50%        5250.172771
# 75%        6818.181818
# max      176470.588235
# Name: price_per_sq_ft, dtype: float64

# %%
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('location'):
        m = np.mean(subdf.price_per_sq_ft)
        st = np.std(subdf.price_per_sq_ft)
        reduced_df = subdf[(subdf.price_per_sq_ft>(m-st)) & (subdf.price_per_sq_ft<=(m+st))]
        df_out = pd.concat([df_out,reduced_df],ignore_index=True)
    return df_out

# %% [markdown]
# This line 6 filters out the outliers from the current location group. It creates a new DataFrame called reduced_df containing rows where the 'price_per_sq_ft' values fall within one standard deviation from the mean.

# %% [markdown]
# One standard deviation from the mean is a statistical measure used to understand the spread or dispersion of data points around the average (mean) value. In a normal or Gaussian distribution, approximately 68% of the data falls within one standard deviation of the mean.
#
# Mathematically, for a dataset with a mean (μ) and a standard deviation (σ), the range of values within one standard deviation from the mean is given by:
#
# Lower Bound: μ - σ
# Upper Bound: μ + σ

# %%
df2 = remove_pps_outliers(df1)
df2.shape
# Out:
# (10007, 6)

# %%
len(df2['location'].unique())
# Out:
# 241

# %%
df2
# Out:
#                   location  total_sqft  bath   price  BHK  price_per_sq_ft
# 0      1st Block Jayanagar      2850.0   4.0  428.00    4     15017.543860
# 1      1st Block Jayanagar      1630.0   3.0  194.00    3     11901.840491
# 2      1st Block Jayanagar      1875.0   2.0  235.00    3     12533.333333
# 3      1st Block Jayanagar      1200.0   2.0  130.00    3     10833.333333
# 4      1st Block Jayanagar      1235.0   2.0  148.00    2     11983.805668
# ...                    ...         ...   ...     ...  ...              ...
# 10002                other      1353.0   2.0  110.00    2      8130.081301
# 10003                other       812.0   1.0   26.00    1      3201.970443
# 10004                other      1440.0   2.0   63.93    3      4439.583333
# 10005                other      1075.0   2.0   48.00    2      4465.116279
# 10006                other      3600.0   5.0  400.00    4     11111.111111
#
# [10007 rows x 6 columns]

# %%
def plot_scatter_chart(df,location):
    bhk2=df[(df.location==location)&(df.BHK==2)]
    bhk3=df[(df.location==location)&(df.BHK==3)]
    matplotlib.rcParams["figure.figsize"] = (20,10)
    plt.scatter(bhk2.total_sqft,bhk2.price_per_sq_ft,color='blue',label='2bhk',s=50)
    plt.scatter(bhk3.total_sqft,bhk3.price_per_sq_ft,marker='+',color='green',label='3 bhk',s=50)
    plt.xlabel("total sq ft area")
    plt.ylabel("price per square feet")
    plt.title("location")
    plt.legend()

# %%
df2['location'].unique()
# Out:
# array(['1st Block Jayanagar', '1st Phase JP Nagar',
#        '2nd Phase Judicial Layout', '2nd Stage Nagarbhavi',
#        '5th Block Hbr Layout', '5th Phase JP Nagar', '6th Phase JP Nagar',
#        '7th Phase JP Nagar', '8th Phase JP Nagar', '9th Phase JP Nagar',
#        'AECS Layout', 'Abbigere', 'Akshaya Nagar', 'Ambalipura',
#        'Ambedkar Nagar', 'Amruthahalli', 'Anandapura', 'Ananth Nagar',
#        'Anekal', 'Anjanapura', 'Ardendale', 'Arekere', 'Attibele',
#        'BEML Layout', 'BTM 2nd Stage', 'BTM Layout', 'Babusapalaya',
#        'Badavala Nagar', 'Balagere', 'Banashankari',
#        'Banashankari Stage II', 'Banashankari Stage III',
#        'Banashankari Stage V', 'Banashankari Stage VI', 'Banaswadi',
#        'Banjara Layout', 'Bannerghatta', 'Bannerghatta Road',
#        'Basavangudi', 'Basaveshwara Nagar', 'Battarahalli', 'Begur',
#        'Begur Road', 'Bellandur', 'Benson Town', 'Bharathi Nagar',
# ...

# %%
plot_scatter_chart(df2,'Akshaya Nagar')

# %%
plot_scatter_chart(df2,'EPIP Zone')

# %%
plot_scatter_chart(df2,'other')

# %%
plt.hist(df2.price_per_sq_ft,rwidth=0.8)
plt.xlabel("price per sq ft")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
df.bath.unique()
# Out:
# array([ 2.,  5.,  3.,  4.,  1.,  8.,  6.,  7.,  9., 14., 12., 16., 10.,
#        13.])

# %%
df[df.bath>10]
# Out:
#              location  total_sqft  bath   price  BHK  price_per_sq_ft  \
# 1078            other      3300.0  14.0   500.0    9     15151.515152
# 3096            other     12000.0  12.0   525.0   10      4375.000000
# 3609            other     10000.0  16.0   550.0   16      5500.000000
# 7979            other      6000.0  12.0   150.0   11      2500.000000
# 8636   Neeladri Nagar      4000.0  12.0   160.0   10      4000.000000
# 9935            other      5425.0  13.0   275.0   13      5069.124424
# 13067           other      7150.0  13.0  3600.0   10     50349.650350
#
#        total_sqft_per_BHK
# 1078           366.666667
# 3096          1200.000000
# 3609           625.000000
# 7979           545.454545
# 8636           400.000000
# 9935           417.307692
# 13067          715.000000

# %%
plt.hist(df2.bath,rwidth=0.8)
plt.xlabel("no of bathroom")
plt.ylabel("totoal bath")
# Out:
# Text(0, 0.5, 'totoal bath')

# %%
df2[df2.bath>df2.BHK+2]
# Out:
#            location  total_sqft  bath   price  BHK  price_per_sq_ft
# 1567  Chikkabanavar      2460.0   7.0    80.0    4      3252.032520
# 5098     Nagasandra      7000.0   8.0   450.0    4      6428.571429
# 6559    Thanisandra      1806.0   6.0   116.0    3      6423.034330
# 8221          other     11338.0   9.0  1000.0    6      8819.897689

# %%
df2=df2[~(df2.bath>df2.BHK+2)]

# %% [markdown]
# removing the rows which have more number of 2 bath than the room since more probably if a house has 3 bhk can have atmost 5 bath not more than 5

# %%
df2[df2.bath>df2.BHK+2]
# Out:
# Empty DataFrame
# Columns: [location, total_sqft, bath, price, BHK, price_per_sq_ft]
# Index: []

# %%
df2
# Out:
#                   location  total_sqft  bath   price  BHK  price_per_sq_ft
# 0      1st Block Jayanagar      2850.0   4.0  428.00    4     15017.543860
# 1      1st Block Jayanagar      1630.0   3.0  194.00    3     11901.840491
# 2      1st Block Jayanagar      1875.0   2.0  235.00    3     12533.333333
# 3      1st Block Jayanagar      1200.0   2.0  130.00    3     10833.333333
# 4      1st Block Jayanagar      1235.0   2.0  148.00    2     11983.805668
# ...                    ...         ...   ...     ...  ...              ...
# 10002                other      1353.0   2.0  110.00    2      8130.081301
# 10003                other       812.0   1.0   26.00    1      3201.970443
# 10004                other      1440.0   2.0   63.93    3      4439.583333
# 10005                other      1075.0   2.0   48.00    2      4465.116279
# 10006                other      3600.0   5.0  400.00    4     11111.111111
#
# [10003 rows x 6 columns]

# %% [markdown]
# now ouer data set is ready for the machine learning but before this we can drop some feature like price per sq ft

# %%
df2.drop('price_per_sq_ft',axis='columns',inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7620\3622340599.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop('price_per_sq_ft',axis='columns',inplace=True)

# %%
df2
# Out:
#                   location  total_sqft  bath   price  BHK
# 0      1st Block Jayanagar      2850.0   4.0  428.00    4
# 1      1st Block Jayanagar      1630.0   3.0  194.00    3
# 2      1st Block Jayanagar      1875.0   2.0  235.00    3
# 3      1st Block Jayanagar      1200.0   2.0  130.00    3
# 4      1st Block Jayanagar      1235.0   2.0  148.00    2
# ...                    ...         ...   ...     ...  ...
# 10002                other      1353.0   2.0  110.00    2
# 10003                other       812.0   1.0   26.00    1
# 10004                other      1440.0   2.0   63.93    3
# 10005                other      1075.0   2.0   48.00    2
# 10006                other      3600.0   5.0  400.00    4
#
# [10003 rows x 5 columns]

# %%
df2.location
# Out:
# 0        1st Block Jayanagar
# 1        1st Block Jayanagar
# 2        1st Block Jayanagar
# 3        1st Block Jayanagar
# 4        1st Block Jayanagar
#                 ...
# 10002                  other
# 10003                  other
# 10004                  other
# 10005                  other
# 10006                  other
# Name: location, Length: 10003, dtype: object

# %% [markdown]
# since df.location is a text coloum that is categorical information  we have to convert it into numeric value so that we can use our machine learning algorithim for this we will introduce the dumies coloum or we will do one hot encoding

# %%
dumies=pd.get_dummies(df2.location)

# %%
dumies
# Out:
#        1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0                     True               False                      False
# 1                     True               False                      False
# 2                     True               False                      False
# 3                     True               False                      False
# 4                     True               False                      False
# ...                    ...                 ...                        ...
# 10002                False               False                      False
# 10003                False               False                      False
# 10004                False               False                      False
# 10005                False               False                      False
# 10006                False               False                      False
#
#        2nd Stage Nagarbhavi  5th Block Hbr Layout  5th Phase JP Nagar  \
# ...

# %%
df3=pd.concat([df2,dumies],axis='columns')

# %%
df3.drop('other',axis='columns',inplace=True)

# %%
df3.head()
# Out:
#               location  total_sqft  bath  price  BHK  1st Block Jayanagar  \
# 0  1st Block Jayanagar      2850.0   4.0  428.0    4                 True
# 1  1st Block Jayanagar      1630.0   3.0  194.0    3                 True
# 2  1st Block Jayanagar      1875.0   2.0  235.0    3                 True
# 3  1st Block Jayanagar      1200.0   2.0  130.0    3                 True
# 4  1st Block Jayanagar      1235.0   2.0  148.0    2                 True
#
#    1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  \
# 0               False                      False                 False
# 1               False                      False                 False
# 2               False                      False                 False
# 3               False                      False                 False
# 4               False                      False                 False
#
#    5th Block Hbr Layout  ...  Vijayanagar  Vishveshwarya Layout  \
# ...

# %%
df3.drop('location',axis='columns',inplace=True)

# %%
df3.isnull().sum()
# Out:
# total_sqft             0
# bath                   0
# price                  0
# BHK                    0
# 1st Block Jayanagar    0
#                       ..
# Yelachenahalli         0
# Yelahanka              0
# Yelahanka New Town     0
# Yelenahalli            0
# Yeshwanthpur           0
# Length: 244, dtype: int64

# %%
df3.shape
# Out:
# (10003, 244)

# %%
df3.columns
# Out:
# Index(['total_sqft', 'bath', 'price', 'BHK', '1st Block Jayanagar',
#        '1st Phase JP Nagar', '2nd Phase Judicial Layout',
#        '2nd Stage Nagarbhavi', '5th Block Hbr Layout', '5th Phase JP Nagar',
#        ...
#        'Vijayanagar', 'Vishveshwarya Layout', 'Vishwapriya Layout',
#        'Vittasandra', 'Whitefield', 'Yelachenahalli', 'Yelahanka',
#        'Yelahanka New Town', 'Yelenahalli', 'Yeshwanthpur'],
#       dtype='object', length=244)

# %%
x=df3.drop('price',axis='columns')

# %%
y=df3.price

# %%
x.head(10)
# Out:
#    total_sqft  bath  BHK  1st Block Jayanagar  1st Phase JP Nagar  \
# 0      2850.0   4.0    4                 True               False
# 1      1630.0   3.0    3                 True               False
# 2      1875.0   2.0    3                 True               False
# 3      1200.0   2.0    3                 True               False
# 4      1235.0   2.0    2                 True               False
# 5      2750.0   4.0    4                 True               False
# 6      2450.0   4.0    4                 True               False
# 7      2825.0   4.0    4                False                True
# 8      1875.0   3.0    3                False                True
# 9      2065.0   4.0    3                False                True
#
#    2nd Phase Judicial Layout  2nd Stage Nagarbhavi  5th Block Hbr Layout  \
# 0                      False                 False                 False
# 1                      False                 False                 False
# ...

# %%
y.head(10)
# Out:
# 0    428.0
# 1    194.0
# 2    235.0
# 3    130.0
# 4    148.0
# 5    413.0
# 6    368.0
# 7    250.0
# 8    167.0
# 9    210.0
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=10)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.7891725374910438

# %%
from sklearn.model_selection import ShuffleSplit

# %%
from sklearn.model_selection import cross_val_score

# %%
cv=ShuffleSplit(n_splits=5, random_state=10, test_size=0.2)

# %%
cross_val_score(LinearRegression(), x, y, cv=cv).mean()
# Out:
# 0.8148453680975217

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import Lasso

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
def find_best_model_using_gridsearchcv(X,y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                'fit_intercept': [True, False]
            }
        },
        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1,2],
                'selection': ['random', 'cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['mse','friedman_mse'],
                'splitter': ['best','random']
            }
        }
    }

    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs =  GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
        })

    return pd.DataFrame(scores,columns=['model','best_score','best_params'])

find_best_model_using_gridsearchcv(x,y)
# Out:
# c:\MinGW\python32\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\MinGW\python32\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\MinGW\python32\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\MinGW\python32\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
x.columns
# Out:
# Index(['total_sqft', 'bath', 'BHK', '1st Block Jayanagar',
#        '1st Phase JP Nagar', '2nd Phase Judicial Layout',
#        '2nd Stage Nagarbhavi', '5th Block Hbr Layout', '5th Phase JP Nagar',
#        '6th Phase JP Nagar',
#        ...
#        'Vijayanagar', 'Vishveshwarya Layout', 'Vishwapriya Layout',
#        'Vittasandra', 'Whitefield', 'Yelachenahalli', 'Yelahanka',
#        'Yelahanka New Town', 'Yelenahalli', 'Yeshwanthpur'],
#       dtype='object', length=243)

# %%
def predict_price(location,sqft,bath,bhk):    
    loc_index = np.where(x.columns==location)[0][0]

    X = np.zeros(len(x.columns))
    X[0] = sqft
    X[1] = bath
    X[2] = bhk
    if loc_index >= 0:
        X[loc_index] = 1

    return model.predict([X])[0]

# %%
predict_price('1st Phase JP Nagar',1000, 2, 2)
# Out:
# c:\MinGW\python32\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 95.42992612454707

# %%
import pickle

# %%
import pickle
with open('banglore_home_prices_model.pickle','wb') as f:
    pickle.dump(model,f)

# %%
import json

# %%
data_coloum=[col.lower()   for col in x.columns]

# %%
with open("banglore_home_price_model_coloum.json",'w') as f:
    json.dump(data_coloum,f)
