# %%
import pandas as pd

# %%
df=pd.read_csv("MELBOURNE_HOUSE_PRICES_LESS.csv")

# %%
df
# Out:
#                  Suburb           Address  Rooms Type      Price Method  \
# 0            Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 1            Abbotsford     59A Turner St      3    h  1220000.0      S
# 2            Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3            Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4          Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                 ...               ...    ...  ...        ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 63021        Thomastown    3/1 Travers St      3    u        NaN     PI
# 63022  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.nunique()
# Out:
# Suburb             380
# Address          57754
# Rooms               14
# Type                 3
# Price             3417
# Method               9
# SellerG            476
# Date               112
# Postcode           225
# Regionname           8
# Propertycount      368
# Distance           180
# CouncilArea         34
# dtype: int64

# %%
df.shape
# Out:
# (63023, 13)

# %%
df=df[['Suburb','Rooms','Type','Price','Method','SellerG','Regionname','Propertycount','Distance']]

# %%
df
# Out:
#                  Suburb  Rooms Type      Price Method   SellerG  \
# 0            Abbotsford      3    h  1490000.0      S    Jellis
# 1            Abbotsford      3    h  1220000.0      S  Marshall
# 2            Abbotsford      3    h  1420000.0      S    Nelson
# 3            Aberfeldie      3    h  1515000.0      S     Barry
# 4          Airport West      2    h   670000.0      S    Nelson
# ...                 ...    ...  ...        ...    ...       ...
# 63018     Roxburgh Park      3    h   566000.0      S     Raine
# 63019     Roxburgh Park      3    h   500000.0      S     Raine
# 63020     Roxburgh Park      3    h   545000.0      S     Raine
# 63021        Thomastown      3    u        NaN     PI     Barry
# 63022  Williams Landing      4    h        NaN     SP    Aussie
#
#                   Regionname  Propertycount  Distance
# 0      Northern Metropolitan           4019       3.0
# 1      Northern Metropolitan           4019       3.0
# ...

# %%
df.shape
# Out:
# (63023, 9)

# %%
df.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Price            14590
# Method               0
# SellerG              0
# Regionname           0
# Propertycount        0
# Distance             0
# dtype: int64

# %%
df.dropna(inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_8384\1379821321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df
# Out:
#               Suburb  Rooms Type      Price Method   SellerG  \
# 0         Abbotsford      3    h  1490000.0      S    Jellis
# 1         Abbotsford      3    h  1220000.0      S  Marshall
# 2         Abbotsford      3    h  1420000.0      S    Nelson
# 3         Aberfeldie      3    h  1515000.0      S     Barry
# 4       Airport West      2    h   670000.0      S    Nelson
# ...              ...    ...  ...        ...    ...       ...
# 63016      Frankston      2    u   347700.0     SP    Aquire
# 63017        Preston      3    h   808000.0      S        RW
# 63018  Roxburgh Park      3    h   566000.0      S     Raine
# 63019  Roxburgh Park      3    h   500000.0      S     Raine
# 63020  Roxburgh Park      3    h   545000.0      S     Raine
#
#                        Regionname  Propertycount  Distance
# 0           Northern Metropolitan           4019       3.0
# 1           Northern Metropolitan           4019       3.0
# ...

# %%
df.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# dtype: int64

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#        Rooms      Price  Propertycount  Distance  Suburb_Aberfeldie  \
# 0          3  1490000.0           4019       3.0              False
# 1          3  1220000.0           4019       3.0              False
# 2          3  1420000.0           4019       3.0              False
# 3          3  1515000.0           1543       7.5               True
# 4          2   670000.0           3464      10.4              False
# ...      ...        ...            ...       ...                ...
# 63016      2   347700.0          17055      38.0              False
# 63017      3   808000.0          14577       8.4              False
# 63018      3   566000.0           5833      20.6              False
# 63019      3   500000.0           5833      20.6              False
# 63020      3   545000.0           5833      20.6              False
#
#        Suburb_Airport West  Suburb_Albanvale  Suburb_Albert Park  \
# 0                    False             False               False
# ...

# %%
x=df.drop('Price',axis=1)

# %%
y=df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_trian,y_Test=train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_trian)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_Test)
# Out:
# 0.6464151438138608

# %%
model.score(x_train,y_trian)
# Out:
# 0.666576695600316

# %%
from sklearn import linear_model

# %%
linear_reg=linear_model.Lasso()

# %%
linear_reg.fit(x_train,y_trian)
# Out:
# c:\MinGW\python32\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.000e+15, tolerance: 1.198e+12
#   model = cd_fast.enet_coordinate_descent(
# Lasso()

# %%
linear_reg.score(x_test,y_Test)
# Out:
# 0.6466377880222594

# %%
from sklearn.linear_model import Ridge

# %%
Ridge_Reg=Ridge()

# %%
Ridge_Reg.fit(x_test,y_Test)
# Out:
# Ridge()

# %%
Ridge_Reg.score(x_test,y_Test)
# Out:
# 0.6662755084036212
